# %% [markdown]
# # Creating and Backtesting RSI Strategies

# %% [markdown]
# ## Getting the Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn")
# Out:
# C:\Users\gupta\AppData\Local\Temp\ipykernel_32480\1123596123.py:4: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
data = pd.read_csv("eurusd.csv", parse_dates = ["Date"], index_col = "Date")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 data = pd.read_csv("eurusd.csv", parse_dates = ["Date"], index_col = "Date")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:678, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     663 kwds_defaults = _refine_defaults_read(
#     664     dialect,
#     665     delimiter,
#    (...)
#     674     defaults={"delimiter": ","},
#     675 )
#     676 kwds.update(kwds_defaults)
# --> 678 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:932, in TextFileReader.__init__(self, f, engine, **kwds)
#     929     self.options["has_index_names"] = kwds["has_index_names"]
#     931 self.handles: IOHandles | None = None
# --> 932 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1216, in TextFileReader._make_engine(self, f, engine)
#    1212     mode = "rb"
#    1213 # error: No overload variant of "get_handle" matches argument types
#    1214 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216 self.handles = get_handle(  # type: ignore[call-overload]
#    1217     f,
#    1218     mode,
#    1219     encoding=self.options.get("encoding", None),
#    1220     compression=self.options.get("compression", None),
#    1221     memory_map=self.options.get("memory_map", False),
#    1222     is_text=is_text,
#    1223     errors=self.options.get("encoding_errors", "strict"),
#    1224     storage_options=self.options.get("storage_options", None),
#    1225 )
#    1226 assert self.handles is not None
#    1227 f = self.handles.handle
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:786, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     781 elif isinstance(handle, str):
#     782     # Check whether the filename is to be opened in binary mode.
#     783     # Binary mode does not support 'encoding' and 'newline'.
#     784     if ioargs.encoding and "b" not in ioargs.mode:
#     785         # Encoding
# --> 786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#     789             encoding=ioargs.encoding,
#     790             errors=errors,
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
#     795         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'eurusd.csv'

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined

# %%
data.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 data.info()
#
# NameError: name 'data' is not defined

# %%
data.plot(figsize = (12, 8), title = "EUR/USD", fontsize = 12)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 data.plot(figsize = (12, 8), title = "EUR/USD", fontsize = 12)
#       2 plt.show()
#
# NameError: name 'data' is not defined

# %% [markdown]
# ## Defining an RSI Strategy (Part 1)

# %%
data
# Out:
#                price
# Date
# 2004-01-01  1.258194
# 2004-01-02  1.258194
# 2004-01-05  1.268698
# 2004-01-06  1.272103
# 2004-01-07  1.264095
# ...              ...
# 2020-06-24  1.131235
# 2020-06-25  1.125087
# 2020-06-26  1.122208
# 2020-06-29  1.122586
# 2020-06-30  1.124720
#
# [4275 rows x 1 columns]

# %%
data.price.diff()
# Out:
# Date
# 2004-01-01         NaN
# 2004-01-02    0.000000
# 2004-01-05    0.010504
# 2004-01-06    0.003405
# 2004-01-07   -0.008008
#                 ...
# 2020-06-24    0.003267
# 2020-06-25   -0.006147
# 2020-06-26   -0.002879
# 2020-06-29    0.000378
# 2020-06-30    0.002134
# Name: price, Length: 4275, dtype: float64

# %% [markdown]
# __U:__ <br>
# - if __positive__ price change ("up"): __price change__<br>
# - if __negative__ price change ("down"): __0__

# %%
data["U"] = np.where(data.price.diff() > 0, data.price.diff(), 0)

# %% [markdown]
# __D:__ <br>
# - if __positive__ price change ("up"): __0__<br>
# - if __negative__ price change ("down"): __-price change__

# %%
data["D"] = np.where(data.price.diff() < 0, -data.price.diff(), 0)

# %%
data
# Out:
#                price         U         D
# Date
# 2004-01-01  1.258194  0.000000  0.000000
# 2004-01-02  1.258194  0.000000  0.000000
# 2004-01-05  1.268698  0.010504  0.000000
# 2004-01-06  1.272103  0.003405  0.000000
# 2004-01-07  1.264095  0.000000  0.008008
# ...              ...       ...       ...
# 2020-06-24  1.131235  0.003267  0.000000
# 2020-06-25  1.125087  0.000000  0.006147
# 2020-06-26  1.122208  0.000000  0.002879
# 2020-06-29  1.122586  0.000378  0.000000
# 2020-06-30  1.124720  0.002134  0.000000
#
# [4275 rows x 3 columns]

# %% [markdown]
# __Calculate Moving Averages for U and D__ (alternative: exponential smoothing)

# %%
periods = 20

# %%
data["MA_U"] = data.U.rolling(periods).mean()

# %%
data["MA_D"] = data.D.rolling(periods).mean()

# %%
data
# Out:
#                price         U         D      MA_U      MA_D
# Date
# 2004-01-01  1.258194  0.000000  0.000000       NaN       NaN
# 2004-01-02  1.258194  0.000000  0.000000       NaN       NaN
# 2004-01-05  1.268698  0.010504  0.000000       NaN       NaN
# 2004-01-06  1.272103  0.003405  0.000000       NaN       NaN
# 2004-01-07  1.264095  0.000000  0.008008       NaN       NaN
# ...              ...       ...       ...       ...       ...
# 2020-06-24  1.131235  0.003267  0.000000  0.003182  0.001530
# 2020-06-25  1.125087  0.000000  0.006147  0.003007  0.001837
# 2020-06-26  1.122208  0.000000  0.002879  0.002696  0.001981
# 2020-06-29  1.122586  0.000378  0.000000  0.002518  0.001981
# 2020-06-30  1.124720  0.002134  0.000000  0.002587  0.001981
#
# [4275 rows x 5 columns]

# %% [markdown]
# __Calculate Relative Strength Index (RSI)__

# %% [markdown]
# Ratio of ups to downs

# %%
data["RSI"] = data.MA_U / (data.MA_U + data.MA_D) * 100

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#                price         U         D      MA_U      MA_D        RSI
# Date
# 2004-01-28  1.244199  0.000000  0.019496  0.004610  0.005310  46.472973
# 2004-01-29  1.241003  0.000000  0.003196  0.004610  0.005470  45.736150
# 2004-01-30  1.246805  0.005802  0.000000  0.004900  0.005470  47.254310
# 2004-02-02  1.243302  0.000000  0.003503  0.004375  0.005645  43.663573
# 2004-02-03  1.253494  0.010192  0.000000  0.004714  0.005645  45.509086
# ...              ...       ...       ...       ...       ...        ...
# 2020-06-24  1.131235  0.003267  0.000000  0.003182  0.001530  67.538713
# 2020-06-25  1.125087  0.000000  0.006147  0.003007  0.001837  62.077668
# 2020-06-26  1.122208  0.000000  0.002879  0.002696  0.001981  57.643190
# 2020-06-29  1.122586  0.000378  0.000000  0.002518  0.001981  55.965360
# 2020-06-30  1.124720  0.002134  0.000000  0.002587  0.001981  56.636052
#
# [4256 rows x 6 columns]

# %%
data.loc["2019", ["price", "RSI"]].plot(figsize = (12, 8), secondary_y = "RSI")
plt.show()

# %% [markdown]
# Instruments which have had
# - __more or stronger positive changes__ have a __higher RSI__
# - __more or stronger negative changes__ have a __lower RSI__

# %% [markdown]
# ## Defining an RSI Strategy (Part 2)

# %% [markdown]
# - Extreme __high RSI__ (>70) indicates __overbought__ instrument -> __sell__
# - Extreme __low RSI__ (<30) indicates __oversold__ instrument -> __buy__

# %%
rsi_upper = 70
rsi_lower = 30

# %%
data.loc["2010", ["RSI"]].plot(figsize = (12, 8))
plt.hlines(y = rsi_upper, xmin = data.index[0], xmax = data.index[-1], label = "RSI_Upper", color = "r")
plt.hlines(y = rsi_lower, xmin = data.index[0], xmax = data.index[-1], label = "RSI_Lower", color = "g")
plt.yticks(ticks = range(0, 100, 10))
plt.legend()
plt.show()

# %%
data["position"] = np.where(data.RSI > rsi_upper, -1, np.nan) # 1. overbought -> go short

# %%
data["position"] = np.where(data.RSI < rsi_lower, 1, data.position) # 2. oversold -> go long

# %%
data.position = data.position.fillna(0) # 3. where 1 & 2 isn´t applicable -> neutral

# %%
data
# Out:
#                price         U         D      MA_U      MA_D        RSI  \
# Date
# 2004-01-28  1.244199  0.000000  0.019496  0.004610  0.005310  46.472973
# 2004-01-29  1.241003  0.000000  0.003196  0.004610  0.005470  45.736150
# 2004-01-30  1.246805  0.005802  0.000000  0.004900  0.005470  47.254310
# 2004-02-02  1.243302  0.000000  0.003503  0.004375  0.005645  43.663573
# 2004-02-03  1.253494  0.010192  0.000000  0.004714  0.005645  45.509086
# ...              ...       ...       ...       ...       ...        ...
# 2020-06-24  1.131235  0.003267  0.000000  0.003182  0.001530  67.538713
# 2020-06-25  1.125087  0.000000  0.006147  0.003007  0.001837  62.077668
# 2020-06-26  1.122208  0.000000  0.002879  0.002696  0.001981  57.643190
# 2020-06-29  1.122586  0.000378  0.000000  0.002518  0.001981  55.965360
# 2020-06-30  1.124720  0.002134  0.000000  0.002587  0.001981  56.636052
#
#             position
# Date
# 2004-01-28       0.0
# 2004-01-29       0.0
# 2004-01-30       0.0
# 2004-02-02       0.0
# 2004-02-03       0.0
# ...              ...
# 2020-06-24       0.0
# 2020-06-25       0.0
# 2020-06-26       0.0
# 2020-06-29       0.0
# 2020-06-30       0.0
#
# [4256 rows x 7 columns]

# %%
data.position.value_counts()
# Out:
#  0.0    3637
# -1.0     316
#  1.0     303
# Name: position, dtype: int64

# %%
data.loc[:, ["RSI", "position"]].plot(figsize = (12, 8), fontsize = 12, 
                                                      secondary_y = "position", title = "EUR/USD")
plt.show()

# %%
data.loc["06-2010":"07-2010", ["RSI", "position"]].plot(figsize = (12, 8), fontsize = 12, 
                                                      secondary_y = "position", title = "EUR/USD")
plt.show()

# %% [markdown]
# ## Vectorized Strategy Backtesting

# %%
data
# Out:
#                price         U         D      MA_U      MA_D        RSI  \
# Date
# 2004-01-28  1.244199  0.000000  0.019496  0.004610  0.005310  46.472973
# 2004-01-29  1.241003  0.000000  0.003196  0.004610  0.005470  45.736150
# 2004-01-30  1.246805  0.005802  0.000000  0.004900  0.005470  47.254310
# 2004-02-02  1.243302  0.000000  0.003503  0.004375  0.005645  43.663573
# 2004-02-03  1.253494  0.010192  0.000000  0.004714  0.005645  45.509086
# ...              ...       ...       ...       ...       ...        ...
# 2020-06-24  1.131235  0.003267  0.000000  0.003182  0.001530  67.538713
# 2020-06-25  1.125087  0.000000  0.006147  0.003007  0.001837  62.077668
# 2020-06-26  1.122208  0.000000  0.002879  0.002696  0.001981  57.643190
# 2020-06-29  1.122586  0.000378  0.000000  0.002518  0.001981  55.965360
# 2020-06-30  1.124720  0.002134  0.000000  0.002587  0.001981  56.636052
#
#             position
# Date
# 2004-01-28       0.0
# 2004-01-29       0.0
# 2004-01-30       0.0
# 2004-02-02       0.0
# 2004-02-03       0.0
# ...              ...
# 2020-06-24       0.0
# 2020-06-25       0.0
# 2020-06-26       0.0
# 2020-06-29       0.0
# 2020-06-30       0.0
#
# [4256 rows x 7 columns]

# %%
data["returns"] = np.log(data.price.div(data.price.shift(1)))

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#                price         U         D      MA_U      MA_D        RSI  \
# Date
# 2004-01-29  1.241003  0.000000  0.003196  0.004610  0.005470  45.736150
# 2004-01-30  1.246805  0.005802  0.000000  0.004900  0.005470  47.254310
# 2004-02-02  1.243302  0.000000  0.003503  0.004375  0.005645  43.663573
# 2004-02-03  1.253494  0.010192  0.000000  0.004714  0.005645  45.509086
# 2004-02-04  1.253997  0.000503  0.000000  0.004740  0.005244  47.471521
# ...              ...       ...       ...       ...       ...        ...
# 2020-06-24  1.131235  0.003267  0.000000  0.003182  0.001530  67.538713
# 2020-06-25  1.125087  0.000000  0.006147  0.003007  0.001837  62.077668
# 2020-06-26  1.122208  0.000000  0.002879  0.002696  0.001981  57.643190
# 2020-06-29  1.122586  0.000378  0.000000  0.002518  0.001981  55.965360
# 2020-06-30  1.124720  0.002134  0.000000  0.002587  0.001981  56.636052
#
#             position   returns
# Date
# 2004-01-29       0.0 -0.002572
# 2004-01-30       0.0  0.004665
# 2004-02-02       0.0 -0.002814
# 2004-02-03       0.0  0.008164
# 2004-02-04       0.0  0.000401
# ...              ...       ...
# 2020-06-24       0.0  0.002892
# 2020-06-25       0.0 -0.005449
# 2020-06-26       0.0 -0.002562
# 2020-06-29       0.0  0.000337
# 2020-06-30       0.0  0.001899
#
# [4255 rows x 8 columns]

# %%
data["strategy"] = data.position.shift(1) * data["returns"]

# %%
data
# Out:
#                price         U         D      MA_U      MA_D        RSI  \
# Date
# 2004-01-29  1.241003  0.000000  0.003196  0.004610  0.005470  45.736150
# 2004-01-30  1.246805  0.005802  0.000000  0.004900  0.005470  47.254310
# 2004-02-02  1.243302  0.000000  0.003503  0.004375  0.005645  43.663573
# 2004-02-03  1.253494  0.010192  0.000000  0.004714  0.005645  45.509086
# 2004-02-04  1.253997  0.000503  0.000000  0.004740  0.005244  47.471521
# ...              ...       ...       ...       ...       ...        ...
# 2020-06-24  1.131235  0.003267  0.000000  0.003182  0.001530  67.538713
# 2020-06-25  1.125087  0.000000  0.006147  0.003007  0.001837  62.077668
# 2020-06-26  1.122208  0.000000  0.002879  0.002696  0.001981  57.643190
# 2020-06-29  1.122586  0.000378  0.000000  0.002518  0.001981  55.965360
# 2020-06-30  1.124720  0.002134  0.000000  0.002587  0.001981  56.636052
#
#             position   returns  strategy
# Date
# 2004-01-29       0.0 -0.002572       NaN
# 2004-01-30       0.0  0.004665       0.0
# 2004-02-02       0.0 -0.002814      -0.0
# 2004-02-03       0.0  0.008164       0.0
# 2004-02-04       0.0  0.000401       0.0
# ...              ...       ...       ...
# 2020-06-24       0.0  0.002892       0.0
# 2020-06-25       0.0 -0.005449      -0.0
# 2020-06-26       0.0 -0.002562      -0.0
# 2020-06-29       0.0  0.000337       0.0
# 2020-06-30       0.0  0.001899       0.0
#
# [4255 rows x 9 columns]

# %%
data.dropna(inplace = True)

# %%
ptc = 0.00007

# %%
data["trades"] = data.position.diff().fillna(0).abs()

# %%
data.trades.value_counts()
# Out:
# 0.0    3926
# 1.0     328
# Name: trades, dtype: int64

# %%
data["strategy_net"] = data.strategy - data.trades * ptc

# %%
data["creturns"] = data["returns"].cumsum().apply(np.exp)
data["cstrategy"] = data["strategy"].cumsum().apply(np.exp)
data["cstrategy_net"] = data["strategy_net"].cumsum().apply(np.exp)

# %%
data
# Out:
#                price         U         D      MA_U      MA_D        RSI  \
# Date
# 2004-01-30  1.246805  0.005802  0.000000  0.004900  0.005470  47.254310
# 2004-02-02  1.243302  0.000000  0.003503  0.004375  0.005645  43.663573
# 2004-02-03  1.253494  0.010192  0.000000  0.004714  0.005645  45.509086
# 2004-02-04  1.253997  0.000503  0.000000  0.004740  0.005244  47.471521
# 2004-02-05  1.257197  0.003200  0.000000  0.004229  0.005244  44.642922
# ...              ...       ...       ...       ...       ...        ...
# 2020-06-24  1.131235  0.003267  0.000000  0.003182  0.001530  67.538713
# 2020-06-25  1.125087  0.000000  0.006147  0.003007  0.001837  62.077668
# 2020-06-26  1.122208  0.000000  0.002879  0.002696  0.001981  57.643190
# 2020-06-29  1.122586  0.000378  0.000000  0.002518  0.001981  55.965360
# 2020-06-30  1.124720  0.002134  0.000000  0.002587  0.001981  56.636052
#
#             position   returns  strategy  trades  strategy_net  creturns  \
# Date
# 2004-01-30       0.0  0.004665       0.0     0.0           0.0  1.004676
# 2004-02-02       0.0 -0.002814      -0.0     0.0          -0.0  1.001852
# 2004-02-03       0.0  0.008164       0.0     0.0           0.0  1.010066
# 2004-02-04       0.0  0.000401       0.0     0.0           0.0  1.010471
# 2004-02-05       0.0  0.002549       0.0     0.0           0.0  1.013050
# ...              ...       ...       ...     ...           ...       ...
# 2020-06-24       0.0  0.002892       0.0     0.0           0.0  0.911549
# 2020-06-25       0.0 -0.005449      -0.0     0.0          -0.0  0.906595
# 2020-06-26       0.0 -0.002562      -0.0     0.0          -0.0  0.904276
# 2020-06-29       0.0  0.000337       0.0     0.0           0.0  0.904580
# 2020-06-30       0.0  0.001899       0.0     0.0           0.0  0.906300
#
#             cstrategy  cstrategy_net
# Date
# 2004-01-30   1.000000       1.000000
# 2004-02-02   1.000000       1.000000
# 2004-02-03   1.000000       1.000000
# 2004-02-04   1.000000       1.000000
# 2004-02-05   1.000000       1.000000
# ...               ...            ...
# 2020-06-24   1.562978       1.527501
# 2020-06-25   1.562978       1.527501
# 2020-06-26   1.562978       1.527501
# 2020-06-29   1.562978       1.527501
# 2020-06-30   1.562978       1.527501
#
# [4254 rows x 14 columns]

# %%
data[["creturns", "cstrategy", "cstrategy_net"]].plot(figsize = (12 , 8))
plt.show()

# %%
data.loc["2020", ["creturns", "cstrategy", "cstrategy_net"]].plot(figsize = (12 , 8))
plt.show()

# %% [markdown]
# ## Using the RSIBacktester Class

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import brute
plt.style.use("seaborn")
# Out:
# C:\Users\gupta\AppData\Local\Temp\ipykernel_32480\3995735200.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
pd.read_csv("AAPL")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 pd.read_csv("AAPL")
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:678, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, error_bad_lines, warn_bad_lines, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     663 kwds_defaults = _refine_defaults_read(
#     664     dialect,
#     665     delimiter,
#    (...)
#     674     defaults={"delimiter": ","},
#     675 )
#     676 kwds.update(kwds_defaults)
# --> 678 return _read(filepath_or_buffer, kwds)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:575, in _read(filepath_or_buffer, kwds)
#     572 _validate_names(kwds.get("names", None))
#     574 # Create the parser.
# --> 575 parser = TextFileReader(filepath_or_buffer, **kwds)
#     577 if chunksize or iterator:
#     578     return parser
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:932, in TextFileReader.__init__(self, f, engine, **kwds)
#     929     self.options["has_index_names"] = kwds["has_index_names"]
#     931 self.handles: IOHandles | None = None
# --> 932 self._engine = self._make_engine(f, self.engine)
#
# File ~\anaconda3\lib\site-packages\pandas\io\parsers\readers.py:1216, in TextFileReader._make_engine(self, f, engine)
#    1212     mode = "rb"
#    1213 # error: No overload variant of "get_handle" matches argument types
#    1214 # "Union[str, PathLike[str], ReadCsvBuffer[bytes], ReadCsvBuffer[str]]"
#    1215 # , "str", "bool", "Any", "Any", "Any", "Any", "Any"
# -> 1216 self.handles = get_handle(  # type: ignore[call-overload]
#    1217     f,
#    1218     mode,
#    1219     encoding=self.options.get("encoding", None),
#    1220     compression=self.options.get("compression", None),
#    1221     memory_map=self.options.get("memory_map", False),
#    1222     is_text=is_text,
#    1223     errors=self.options.get("encoding_errors", "strict"),
#    1224     storage_options=self.options.get("storage_options", None),
#    1225 )
#    1226 assert self.handles is not None
#    1227 f = self.handles.handle
#
# File ~\anaconda3\lib\site-packages\pandas\io\common.py:786, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     781 elif isinstance(handle, str):
#     782     # Check whether the filename is to be opened in binary mode.
#     783     # Binary mode does not support 'encoding' and 'newline'.
#     784     if ioargs.encoding and "b" not in ioargs.mode:
#     785         # Encoding
# --> 786         handle = open(
#     787             handle,
#     788             ioargs.mode,
#     789             encoding=ioargs.encoding,
#     790             errors=errors,
#     791             newline="",
#     792         )
#     793     else:
#     794         # Binary mode
#     795         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'AAPL'

# %%
from RSIBacktester import RSIBacktester as RSI

# %%
from RSIBacktesternew import RSIBacktester as RSI
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 from RSIBacktesternew import RSIBacktester as RSI
#
# ModuleNotFoundError: No module named 'RSIBacktesternew'

# %%
ptc = 0.00007

# %%
tester = RSI("INTC", periods = 20, rsi_upper = 70, rsi_lower = 30,
              start = "2020-01-01", end = "2023-02-02", tc = ptc)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester
# Out:
# RSIBacktester(symbol = INTC, RSI(20, 70, 30), start = 2020-01-01, end = 2023-02-02)

# %%
tester.data
# Out:
#                 price   returns         U         D    MA_U    MA_D        RSI
# Date
# 2020-01-02  60.840000       NaN  0.000000  0.000000     NaN     NaN        NaN
# 2020-01-03  60.099998 -0.012238  0.000000  0.740002     NaN     NaN        NaN
# 2020-01-06  59.930000 -0.002833  0.000000  0.169998     NaN     NaN        NaN
# 2020-01-07  58.930000 -0.016827  0.000000  1.000000     NaN     NaN        NaN
# 2020-01-08  58.970001  0.000679  0.040001  0.000000     NaN     NaN        NaN
# ...               ...       ...       ...       ...     ...     ...        ...
# 2023-01-26  30.090000  0.013046  0.389999  0.000000  0.3555  0.1480  70.605755
# 2023-01-27  28.160000 -0.066290  0.000000  1.930000  0.3555  0.2245  61.293097
# 2023-01-30  27.950001 -0.007485  0.000000  0.209999  0.3220  0.2350  57.809700
# 2023-01-31  28.260000  0.011030  0.309999  0.000000  0.3265  0.2350  58.147817
# 2023-02-01  29.070000  0.028259  0.809999  0.000000  0.3520  0.2350  59.965928
#
# [777 rows x 7 columns]

# %%
tester.test_strategy()
# Out:
# (1.255861, 0.818521)

# %%
tester.plot_results()

# %%
tester.results
# Out:
#                 price   returns         U         D    MA_U    MA_D  \
# Date
# 2020-01-31  63.930000 -0.038962  0.000000  2.540001  0.6185  0.4640
# 2020-02-03  64.419998  0.007635  0.489998  0.000000  0.6430  0.4270
# 2020-02-04  65.459999  0.016015  1.040001  0.000000  0.6950  0.4185
# 2020-02-05  67.339996  0.028315  1.879997  0.000000  0.7890  0.3685
# 2020-02-06  67.089996 -0.003719  0.000000  0.250000  0.7870  0.3810
# ...               ...       ...       ...       ...     ...     ...
# 2023-01-26  30.090000  0.013046  0.389999  0.000000  0.3555  0.1480
# 2023-01-27  28.160000 -0.066290  0.000000  1.930000  0.3555  0.2245
# 2023-01-30  27.950001 -0.007485  0.000000  0.209999  0.3220  0.2350
# 2023-01-31  28.260000  0.011030  0.309999  0.000000  0.3265  0.2350
# 2023-02-01  29.070000  0.028259  0.809999  0.000000  0.3520  0.2350
#
#                   RSI  position  strategy  trades  creturns  cstrategy
# Date
# 2020-01-31  57.136260       0.0  -0.00000     0.0  0.961787   1.000000
# 2020-02-03  60.093460       0.0   0.00000     0.0  0.969159   1.000000
# 2020-02-04  62.415805       0.0   0.00000     0.0  0.984805   1.000000
# 2020-02-05  68.164143       0.0   0.00000     0.0  1.013089   1.000000
# 2020-02-06  67.380132       0.0  -0.00000     0.0  1.009327   1.000000
# ...               ...       ...       ...     ...       ...        ...
# 2023-01-26  70.605755      -1.0  -0.00007     1.0  0.452685   1.175391
# 2023-01-27  61.293097       0.0   0.06622     1.0  0.423650   1.255861
# 2023-01-30  57.809700       0.0  -0.00000     0.0  0.420490   1.255861
# 2023-01-31  58.147817       0.0   0.00000     0.0  0.425154   1.255861
# 2023-02-01  59.965928       0.0   0.00000     0.0  0.437340   1.255861
#
# [757 rows x 12 columns]

# %%
tester.optimize_parameters((5, 20, 1), (65, 80, 1), (20, 35, 1)) # higher volatility
# Out:
# (array([14., 65., 24.]), 2.711653)

# %%
tester.plot_results()

# %%
tester.optimize_parameters((20, 50, 1), (65, 95, 1), (15, 35, 1)) # lower volatility
# Out:
# (array([20., 66., 26.]), 2.513512)

# %%
tester.plot_results()

# %%
tester = RSI("3MINDIA.NS", periods = 20, rsi_upper = 70, rsi_lower = 30,
              start = "2010-01-01", end = "2013-08-02", tc = ptc)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester
# Out:
# RSIBacktester(symbol = 3MINDIA.NS, RSI(20, 70, 30), start = 2010-01-01, end = 2013-08-02)

# %%
tester.data
# Out:
#                   price   returns          U          D       MA_U       MA_D  \
# Date
# 2010-01-04  1850.750000       NaN   0.000000   0.000000        NaN        NaN
# 2010-01-05  1850.400024 -0.000189   0.000000   0.349976        NaN        NaN
# 2010-01-06  1840.000000 -0.005636   0.000000  10.400024        NaN        NaN
# 2010-01-07  1855.000000  0.008119  15.000000   0.000000        NaN        NaN
# 2010-01-08  1850.599976 -0.002375   0.000000   4.400024        NaN        NaN
# ...                 ...       ...        ...        ...        ...        ...
# 2013-07-26  3447.350098  0.000116   0.400146   0.000000  18.595020  19.977515
# 2013-07-29  3460.000000  0.003663  12.649902   0.000000  16.667517  19.977515
# 2013-07-30  3508.750000  0.013991  48.750000   0.000000  17.472510  19.977515
# 2013-07-31  3440.949951 -0.019512   0.000000  67.800049  17.472510  20.575012
# 2013-08-01  3455.550049  0.004234  14.600098   0.000000  17.102515  20.575012
#
#                   RSI
# Date
# 2010-01-04        NaN
# 2010-01-05        NaN
# 2010-01-06        NaN
# 2010-01-07        NaN
# 2010-01-08        NaN
# ...               ...
# 2013-07-26  48.207928
# 2013-07-29  45.483702
# 2013-07-30  46.655536
# 2013-07-31  45.922859
# 2013-08-01  45.391819
#
# [889 rows x 7 columns]

# %%
tester.test_strategy()
# Out:
# (0.870641, -1.022811)

# %%
tester.plot_results()

# %%
tester.results
# Out:
#                   price   returns          U          D       MA_U       MA_D  \
# Date
# 2010-02-02  1811.250000 -0.007563   0.000000  13.750000   6.514996   8.489996
# 2010-02-03  1821.349976  0.005561  10.099976   0.000000   7.019995   8.472498
# 2010-02-04  1848.099976  0.014580  26.750000   0.000000   8.357495   7.952496
# 2010-02-05  1844.000000 -0.002221   0.000000   4.099976   7.607495   8.157495
# 2010-02-08  1837.099976 -0.003749   0.000000   6.900024   7.607495   8.282495
# ...                 ...       ...        ...        ...        ...        ...
# 2013-07-26  3447.350098  0.000116   0.400146   0.000000  18.595020  19.977515
# 2013-07-29  3460.000000  0.003663  12.649902   0.000000  16.667517  19.977515
# 2013-07-30  3508.750000  0.013991  48.750000   0.000000  17.472510  19.977515
# 2013-07-31  3440.949951 -0.019512   0.000000  67.800049  17.472510  20.575012
# 2013-08-01  3455.550049  0.004234  14.600098   0.000000  17.102515  20.575012
#
#                   RSI  position  strategy  trades  creturns  cstrategy
# Date
# 2010-02-02  43.418857       0.0      -0.0     0.0  0.992466   1.000000
# 2010-02-03  45.312238       0.0       0.0     0.0  0.998000   1.000000
# 2010-02-04  51.241566       0.0       0.0     0.0  1.012658   1.000000
# 2010-02-05  48.255628       0.0      -0.0     0.0  1.010411   1.000000
# 2010-02-08  47.876021       0.0      -0.0     0.0  1.006630   1.000000
# ...               ...       ...       ...     ...       ...        ...
# 2013-07-26  48.207928       0.0       0.0     0.0  1.888959   0.870641
# 2013-07-29  45.483702       0.0       0.0     0.0  1.895890   0.870641
# 2013-07-30  46.655536       0.0       0.0     0.0  1.922603   0.870641
# 2013-07-31  45.922859       0.0      -0.0     0.0  1.885452   0.870641
# 2013-08-01  45.391819       0.0       0.0     0.0  1.893452   0.870641
#
# [869 rows x 12 columns]

# %%
tester.optimize_parameters((5, 20, 1), (65, 80, 1), (20, 35, 1)) # higher volatility
# Out:
# (array([ 8., 78., 30.]), 1.463368)

# %%
tester.plot_results()

# %% [markdown]
# __USD / GBP__

# %%
tester = RSI("USDGBP=X", periods = 20, rsi_upper = 70, rsi_lower = 30,
              start = "2004-01-01", end = "2020-06-30", tc = 0)

# %%
tester.test_strategy()
# Out:
# (1.060393, -0.414041)

# %%
tester.plot_results()

# %%
tester.optimize_parameters((5, 20, 1), (65, 80, 1), (20, 35, 1)) # high volatility
# Out:
# (array([ 7., 66., 34.]), 1.515508)

# %%
tester.plot_results()

# %% [markdown]
# ## Alternative Strategies and Interpretations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import brute
plt.style.use("seaborn")
from RSIBacktester import RSIBacktester as RSI
# Out:
# C:\Users\gupta\AppData\Local\Temp\ipykernel_26728\1756904354.py:5: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
tester = RSI("EURUSD=X", periods = 20, rsi_upper = 70, rsi_lower = 30,
              start = "2004-01-01", end = "2020-06-30", tc = 0)

# %%
alt = tester.data.dropna()
alt
# Out:
#                price   returns         U         D      MA_U      MA_D  \
# Date
# 2004-01-28  1.244199 -0.015548  0.000000  0.019496  0.004610  0.005310
# 2004-01-29  1.241003 -0.002572  0.000000  0.003196  0.004610  0.005470
# 2004-01-30  1.246805  0.004665  0.005802  0.000000  0.004900  0.005470
# 2004-02-02  1.243302 -0.002814  0.000000  0.003503  0.004375  0.005645
# 2004-02-03  1.253494  0.008164  0.010192  0.000000  0.004714  0.005645
# ...              ...       ...       ...       ...       ...       ...
# 2020-06-24  1.131235  0.002892  0.003267  0.000000  0.003182  0.001530
# 2020-06-25  1.125087 -0.005449  0.000000  0.006147  0.003007  0.001837
# 2020-06-26  1.122208 -0.002562  0.000000  0.002879  0.002696  0.001981
# 2020-06-29  1.122586  0.000337  0.000378  0.000000  0.002518  0.001981
# 2020-06-30  1.124720  0.001899  0.002134  0.000000  0.002587  0.001981
#
#                   RSI
# Date
# 2004-01-28  46.472973
# 2004-01-29  45.736150
# 2004-01-30  47.254310
# 2004-02-02  43.663573
# 2004-02-03  45.509086
# ...               ...
# 2020-06-24  67.538713
# 2020-06-25  62.077668
# 2020-06-26  57.643190
# 2020-06-29  55.965360
# 2020-06-30  56.636052
#
# [4256 rows x 7 columns]

# %% [markdown]
# Convergence:
# - if __Price__ reaches __higher highs__ -> __RSI__ reaches __higher highs__ (confirmation)
# - if __Price__ reaches __lower lows__ -> __RSI__ reaches __lower lows__ (confirmation)

# %%
alt.loc["03-2013":"06-2013", ["price", "RSI"]].plot(figsize = (12, 8), secondary_y = "RSI")
plt.show()

# %% [markdown]
# Divergence:
# - if __Price__ reaches __higher highs__ -> __RSI fails__ to reach higher highs (__Bearish Divergence__)
# - if __Price__ reaches __lower lows__ -> __RSI fails__ to reach lower lows (__Bullish Divergence__)

# %%
alt.loc["03-2016":"06-2016", ["price", "RSI"]].plot(figsize = (12, 8), secondary_y = "RSI")
plt.title("Bearish Divergence", fontsize = 15)
plt.show()

# %%
alt.loc["05-2012":"11-2012", ["price", "RSI"]].plot(figsize = (12, 8), secondary_y = "RSI")
plt.title("Bullish Divergence", fontsize = 15)
plt.show()
