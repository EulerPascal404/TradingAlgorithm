# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
from scipy.optimize import brute
plt.style.use("seaborn")
# Out:
# C:\Users\gupta\AppData\Local\Temp\ipykernel_28844\2560229840.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
start = "2017-01-01"
end = "2022-12-31"
symbol = "AAPL"

df = yf.download(tickers = symbol, start = start, end = end)
df = df["Close"].to_frame()
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                  Close
# Date
# 2017-01-03   29.037500
# 2017-01-04   29.004999
# 2017-01-05   29.152500
# 2017-01-06   29.477501
# 2017-01-09   29.747499
# ...                ...
# 2022-12-23  131.860001
# 2022-12-27  130.029999
# 2022-12-28  126.040001
# 2022-12-29  129.610001
# 2022-12-30  129.929993
#
# [1510 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1510 entries, 2017-01-03 to 2022-12-30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   1510 non-null   float64
# dtypes: float64(1)
# memory usage: 23.6 KB

# %%
import SMABacktester as SMA

# %%
tester = SMA.SMABacktester(symbol, 50, 200, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester
# Out:
# SMABacktester(symbol = AAPL, SMA_S = 50, SMA_L = 200, start = 2017-01-01, end = 2022-12-31)

# %%
tester.test_strategy()
# Out:
# (2.061542, -1.177194)

# %%
tester.results
# Out:
#                  price   returns       SMA_S       SMA_L  position  strategy  \
# Date
# 2017-10-18   39.939999 -0.004434   39.527350   36.469600         1 -0.004434
# 2017-10-19   38.994999 -0.023945   39.501950   36.519550         1 -0.023945
# 2017-10-20   39.062500  0.001730   39.506600   36.569100         1  0.001730
# 2017-10-23   39.042500 -0.000512   39.500050   36.616925         1 -0.000512
# 2017-10-24   39.275002  0.005937   39.486300   36.664562         1  0.005937
# ...                ...       ...         ...         ...       ...       ...
# 2022-12-23  131.860001 -0.002802  144.131800  152.133100        -1  0.002802
# 2022-12-27  130.029999 -0.013976  143.964799  152.009600        -1  0.013976
# 2022-12-28  126.040001 -0.031166  143.637399  151.886700        -1  0.031166
# 2022-12-29  129.610001  0.027931  143.354599  151.759300        -1 -0.027931
# 2022-12-30  129.929993  0.002466  143.075999  151.611000        -1 -0.002466
#
#             creturns  cstrategy
# Date
# 2017-10-18  0.995575   0.995575
# 2017-10-19  0.972020   0.972020
# 2017-10-20  0.973702   0.973702
# 2017-10-23  0.973204   0.973204
# 2017-10-24  0.978999   0.978999
# ...              ...        ...
# 2022-12-23  3.286845   2.031367
# 2022-12-27  3.241229   2.059956
# 2022-12-28  3.141771   2.125167
# 2022-12-29  3.230760   2.066631
# 2022-12-30  3.238736   2.061542
#
# [1310 rows x 8 columns]

# %%
tester.plot_results()

# %%
tester.optimize_parameters((25, 50, 1), (100, 200, 1))
# Out:
# (array([ 48., 129.]), 3.271141)

# %%
tester.plot_results()
