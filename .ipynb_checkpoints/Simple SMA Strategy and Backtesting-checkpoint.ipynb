# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
from scipy.optimize import brute
plt.style.use("seaborn")
# Out:
# C:\Users\gupta\AppData\Local\Temp\ipykernel_38404\2560229840.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
start = "2010-01-01"
end = "2020-12-31"
symbol = "INTC"

df = yf.download(tickers = symbol, start = start, end = end)
df = df["Close"].to_frame()
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                 Close
# Date
# 2010-01-04  20.879999
# 2010-01-05  20.870001
# 2010-01-06  20.799999
# 2010-01-07  20.600000
# 2010-01-08  20.830000
# ...               ...
# 2020-12-23  46.570000
# 2020-12-24  47.070000
# 2020-12-28  47.070000
# 2020-12-29  49.389999
# 2020-12-30  48.750000
#
# [2768 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2768 entries, 2010-01-04 to 2020-12-30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   2768 non-null   float64
# dtypes: float64(1)
# memory usage: 43.2 KB

# %%
import SMABacktester as SMA

# %%
tester = SMA.SMABacktester(symbol, 50, 200, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester
# Out:
# SMABacktester(symbol = INTC, SMA_S = 50, SMA_L = 200, start = 2010-01-01, end = 2020-12-31)

# %%
tester.test_strategy()
# Out:
# (0.379679, -2.160706)

# %%
tester.results[tester.results['position']]
# Out:
#                 price   returns      SMA_S      SMA_L  position  strategy  \
# Date
# 2010-11-18  21.020000 -0.002850  20.334827  20.272535         1  0.002850
# 2010-11-19  21.139999  0.005693  20.389310  20.260563         1  0.005693
# 2010-11-22  21.250000  0.005190  20.440345  20.246408         1  0.005190
# 2010-11-23  21.090000 -0.007558  20.504138  20.236056         1 -0.007558
# 2010-11-24  21.389999  0.014124  20.575517  20.230563         1  0.014124
# ...               ...       ...        ...        ...       ...       ...
# 2020-07-15  59.029999  0.000847  59.991724  59.442958         1  0.000847
# 2020-07-16  59.139999  0.001862  59.859655  59.444296         1  0.001862
# 2020-07-17  60.000000  0.014437  59.710000  59.449718         1  0.014437
# 2020-07-20  61.150002  0.018985  59.623104  59.461972         1  0.018985
# 2020-07-21  60.700001 -0.007386  59.542414  59.468169         1 -0.007386
#
#             creturns  cstrategy
# Date
# 2010-11-18  0.974050   1.026641
# 2010-11-19  0.979611   1.032502
# 2010-11-22  0.984708   1.037875
# 2010-11-23  0.977294   1.030060
# 2010-11-24  0.991196   1.044712
# ...              ...        ...
# 2020-07-15  2.735403   0.986590
# 2020-07-16  2.740500   0.988429
# 2020-07-17  2.780352   1.002802
# 2020-07-20  2.833642   1.022023
# 2020-07-21  2.812790   1.014502
#
# [1522 rows x 8 columns]

# %%
tester.plot_results()

# %%
tester.optimize_parameters((25, 50, 1), (100, 200, 1))
# Out:
# (array([ 29., 142.]), 1.277794)

# %%
tester.plot_results()
