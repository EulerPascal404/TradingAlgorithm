# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import yfinance as yf
from scipy.optimize import brute
plt.style.use("seaborn")
# Out:
# C:\Users\gupta\AppData\Local\Temp\ipykernel_34132\2560229840.py:6: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn")

# %%
start = "1990-01-01"
end = "2005-12-31"
symbol = "AAPL"

df = yf.download(tickers = symbol, start = start, end = end)
df = df["Close"].to_frame()
df
# Out:
# [*********************100%***********************]  1 of 1 completed
#                Close
# Date
# 1990-01-02  0.332589
# 1990-01-03  0.334821
# 1990-01-04  0.335938
# 1990-01-05  0.337054
# 1990-01-08  0.339286
# ...              ...
# 2005-12-23  2.619643
# 2005-12-27  2.651071
# 2005-12-28  2.627500
# 2005-12-29  2.551786
# 2005-12-30  2.567500
#
# [4036 rows x 1 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4036 entries, 1990-01-02 to 2005-12-30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Close   4036 non-null   float64
# dtypes: float64(1)
# memory usage: 63.1 KB

# %%
import SMABacktester as SMA

# %%
tester = SMA.SMABacktester(symbol, 50, 200, start, end)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
tester
# Out:
# SMABacktester(symbol = AAPL, SMA_S = 50, SMA_L = 200, start = 1990-01-01, end = 2005-12-31)

# %%
tester.test_strategy()
# Out:
# (0.925093, -9.437424)

# %%
tester.results
# Out:
#                price   returns     SMA_S     SMA_L  position  strategy  \
# Date
# 1990-10-16  0.223214 -0.104362  0.299710  0.337561        -1  0.104362
# 1990-10-17  0.236607  0.058270  0.297388  0.337070        -1 -0.058270
# 1990-10-18  0.254464  0.072759  0.295312  0.336663        -1 -0.072759
# 1990-10-19  0.280134  0.096109  0.293862  0.336378        -1 -0.096109
# 1990-10-22  0.277902 -0.007999  0.292500  0.336071        -1  0.007999
# ...              ...       ...       ...       ...       ...       ...
# 2005-12-23  2.619643 -0.009093  2.314621  1.715630         1 -0.009093
# 2005-12-27  2.651071  0.011926  2.329071  1.721686         1  0.011926
# 2005-12-28  2.627500 -0.008931  2.343450  1.727509         1 -0.008931
# 2005-12-29  2.551786 -0.029239  2.357193  1.732914         1 -0.029239
# 2005-12-30  2.567500  0.006139  2.369300  1.738207         1  0.006139
#
#              creturns  cstrategy
# Date
# 1990-10-16   0.900899   1.110002
# 1990-10-17   0.954954   1.047171
# 1990-10-18   1.027025   0.973686
# 1990-10-19   1.130630   0.884462
# 1990-10-22   1.121622   0.891566
# ...               ...        ...
# 2005-12-23  10.572967   0.943880
# 2005-12-27  10.699812   0.955204
# 2005-12-28  10.604679   0.946711
# 2005-12-29  10.299094   0.919431
# 2005-12-30  10.362517   0.925093
#
# [3836 rows x 8 columns]

# %%
tester.plot_results()

# %%
tester.optimize_parameters((25, 50, 1), (100, 200, 1))
# Out:
# (array([ 38., 142.]), 10.035477)

# %%
tester.plot_results()
